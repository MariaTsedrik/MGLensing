# %% [markdown]
# # Bias values used for Project 2
#
# ### Bacco's - used as fiducials for tests
# - Linear bias

# %%
# Linear bias
b1_1: 0.90447
b1_2: 1.00594
b1_3: 1.11325
b1_4: 1.22421
b1_5: 1.33736

# HEFT
b1L_1: 0.239
b1L_2: 0.378
b1L_3: 0.525
b1L_4: 0.677
b1L_5: 0.832

b2L_1: 0.46036128
b2L_2: 0.4845956
b2L_3: 0.5480625
b2L_4: 0.65459134
b2L_5: 0.80604922

bs2L_1: 0.131
bs2L_2: 0.15
bs2L_3: 0.17
bs2L_4: 0.19
bs2L_5: 0.21

blaplL_1: 1.832
blaplL_2: 2.102
blaplL_3: 2.377
blaplL_4: 2.655
blaplL_5: 2.934

# %% [markdown]
# ### SRD (Niko's) values (Lagrangian)
#
# Already modified to be used in our code, _i.e._ subtracted 1 from b1 and divided by 2 in the higher order parameters

# %%
# LSST Y1

b1L_1: 0.187684
b1L_2: 0.312375
b1L_3: 0.45121
b1L_4: 0.60626
b1L_5: 0.779385

b2L_1: -0.1322075
b2L_2: -0.0345375
b2L_3: 0.0579305
b2L_4: 0.133662
b2L_5: 0.232387

bs2L_1: 0.1127485
bs2L_2: 0.0036835
bs2L_3: -0.1261985
bs2L_4: -0.285537
bs2L_5: -0.406101

blaplL_1: -0.100126
blaplL_2: -0.1563475
blaplL_3: -0.115281
blaplL_4: 0.1059295
blaplL_5: 0.361450

# LSST Y10
b1L_1 : 1.187684
b1L_2 : 1.213704
b1L_3 : 1.279298
b1L_4 : 1.345371
b1L_5 : 1.414455
b1L_6 : 1.492622
b1L_7 : 1.570881
b1L_8 : 1.650379
b1L_9 : 1.740059
b1L_10: 1.829755

b2L_1 : -0.264415
b2L_2 : -0.223652
b2L_3 : -0.120894
b2L_4 : -0.017386
b2L_5 : 0.079957
b2L_6 : 0.156314
b2L_7 : 0.232763
b2L_8 : 0.31234
b2L_9 : 0.418308
b2L_10: 0.524294

bs2L_1 : 0.225497
bs2L_2 : 0.179978
bs2L_3 : 0.065231
bs2L_4 : -0.050353
bs2L_5 : -0.176854
bs2L_6 : -0.337511
bs2L_7 : -0.498359
bs2L_8 : -0.65399
bs2L_9 : -0.763975
bs2L_10: -0.873978

blaplL_1 :  -0.200252
blaplL_2 :  -0.223716
blaplL_3 :  -0.282866
blaplL_4 :  -0.342448
blaplL_5 :  -0.335438
blaplL_6 :  -0.112397
blaplL_7 :  0.110909
blaplL_8 :  0.338903
blaplL_9 :  0.605845
blaplL_10:  0.872833

# %% [markdown]
# Eulerian

# %%
b1_1 : 1.187256
b1_2 : 1.312369
b1_3 : 1.451258
b1_5 : 1.605669
b1_4 : 1.777521

# %% [markdown]
# ### When sampling $b \times \sigma_8$
#
# These has to be used in the parameter file for the data vector, _i.e._ `params_data.yaml`, while the theory parameter file (with fixed values and prior ranges) the $\sigma_8$ factor is already included by the code (I'm working on making everything authomatic so that we can just use the above values and the code will add $\times\sigma_8$).
#
# Assumed $\sigma_8 = 0.83$ (fiducial value).

# %%
# Linear bias
b1_1: 0.7507101
b1_2: 0.8349302
b1_3: 0.9239975
b1_4: 1.0160943
b1_5: 1.1100088

# HEFT
b1L_1: 0.19837
b1L_2: 0.31374
b1L_3: 0.43575
b1L_4: 0.56191
b1L_5: 0.69056

b2L_1: 0.38209986
b2L_2: 0.40221435
b2L_3: 0.45489188
b2L_4: 0.54331081
b2L_5: 0.66902085

bs2L_1: 0.10873
bs2L_2: 0.1245
bs2L_3: 0.1411
bs2L_4: 0.1577
bs2L_5: 0.1743

blaplL_1: 1.52056
blaplL_2: 1.74466
blaplL_3: 1.97291
blaplL_4: 2.20365
blaplL_5: 2.43522
